# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

dataset = pd .read_csv(r"C:\Users\pdhau\OneDrive\Desktop\Third semester\AI AND ML\taxi_trip_pricing.csv")

# %%
dataset.head()
# Out:
#    Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0             19.35     Morning     Weekday              3.0
# 1             47.59   Afternoon     Weekday              1.0
# 2             36.87     Evening     Weekend              1.0
# 3             30.33     Evening     Weekday              4.0
# 4               NaN     Evening     Weekday              3.0
#
#   Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                Low   Clear       3.56         0.80             0.32
# 1               High   Clear        NaN         0.62             0.43
# 2               High   Clear       2.70         1.21             0.15
# 3                Low     NaN       3.48         0.51             0.15
# 4               High   Clear       2.93         0.63             0.32
#
#    Trip_Duration_Minutes  Trip_Price
# 0                  53.82     36.2624
# 1                  40.57         NaN
# 2                  37.27     52.9032
# ...

# %%
dataset.dropna(inplace=True)

# %%
dataset["Time_of_Day"].value_counts()
# Out:
# Time_of_Day
# Afternoon    220
# Morning      157
# Evening      124
# Night         61
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
dataset["Time_of_Day"] = encoder.fit_transform(dataset["Time_of_Day"])

# %%
dataset.head()
# Out:
#     Trip_Distance_km  Time_of_Day Day_of_Week  Passenger_Count  \
# 0              19.35            2     Weekday              3.0
# 2              36.87            1     Weekend              1.0
# 5               8.64            0     Weekend              2.0
# 12             41.79            3     Weekend              3.0
# 14              9.91            1     Weekday              2.0
#
#    Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                 Low   Clear       3.56         0.80             0.32
# 2                High   Clear       2.70         1.21             0.15
# 5              Medium   Clear       2.55         1.71             0.48
# 12               High   Clear       4.60         1.77             0.11
# 14               High   Clear       2.32         1.26             0.34
#
#     Trip_Duration_Minutes  Trip_Price
# 0                   53.82     36.2624
# 2                   37.27     52.9032
# 5                   89.33     60.2028
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
dataset["Traffic_Conditions"] = encoder.fit_transform(dataset["Traffic_Conditions"])

# %%
dataset.head()
# Out:
#     Trip_Distance_km  Time_of_Day Day_of_Week  Passenger_Count  \
# 0              19.35            2     Weekday              3.0
# 2              36.87            1     Weekend              1.0
# 5               8.64            0     Weekend              2.0
# 12             41.79            3     Weekend              3.0
# 14              9.91            1     Weekday              2.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                    1   Clear       3.56         0.80             0.32
# 2                    0   Clear       2.70         1.21             0.15
# 5                    2   Clear       2.55         1.71             0.48
# 12                   0   Clear       4.60         1.77             0.11
# 14                   0   Clear       2.32         1.26             0.34
#
#     Trip_Duration_Minutes  Trip_Price
# 0                   53.82     36.2624
# 2                   37.27     52.9032
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
dataset["Day_of_Week"] = encoder.fit_transform(dataset["Day_of_Week"])

# %%
dataset.head()
# Out:
#     Trip_Distance_km  Time_of_Day  Day_of_Week  Passenger_Count  \
# 0              19.35            2            0              3.0
# 2              36.87            1            1              1.0
# 5               8.64            0            1              2.0
# 12             41.79            3            1              3.0
# 14              9.91            1            0              2.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                    1   Clear       3.56         0.80             0.32
# 2                    0   Clear       2.70         1.21             0.15
# 5                    2   Clear       2.55         1.71             0.48
# 12                   0   Clear       4.60         1.77             0.11
# 14                   0   Clear       2.32         1.26             0.34
#
#     Trip_Duration_Minutes  Trip_Price
# 0                   53.82     36.2624
# 2                   37.27     52.9032
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
dataset["Weather"] = encoder.fit_transform(dataset["Weather"])

# %%
dataset.head()
# Out:
#     Trip_Distance_km  Time_of_Day  Day_of_Week  Passenger_Count  \
# 0              19.35            2            0              3.0
# 2              36.87            1            1              1.0
# 5               8.64            0            1              2.0
# 12             41.79            3            1              3.0
# 14              9.91            1            0              2.0
#
#     Traffic_Conditions  Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                    1        0       3.56         0.80             0.32
# 2                    0        0       2.70         1.21             0.15
# 5                    2        0       2.55         1.71             0.48
# 12                   0        0       4.60         1.77             0.11
# 14                   0        0       2.32         1.26             0.34
#
#     Trip_Duration_Minutes  Trip_Price
# 0                   53.82     36.2624
# 2                   37.27     52.9032
# ...

# %%
X_feature = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %%
X_feature
# Out:
#      Trip_Distance_km  Time_of_Day  Day_of_Week  Passenger_Count  \
# 0               19.35            2            0              3.0
# 2               36.87            1            1              1.0
# 5                8.64            0            1              2.0
# 12              41.79            3            1              3.0
# 14               9.91            1            0              2.0
# ..                ...          ...          ...              ...
# 990             40.17            1            0              3.0
# 992             14.34            0            0              1.0
# 994             18.69            1            0              3.0
# 995              5.49            0            1              4.0
# 998             47.56            2            0              1.0
#
#      Traffic_Conditions  Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                     1        0       3.56         0.80             0.32
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,_X_test,y_train,y_test = train_test_split(X_feature,y_feature,test_size=0.2,random_state=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 X_train,_X_test,y_train,y_test = train_test_split(X_feature,y_feature,test_size=0.2,random_state=2)
#
# NameError: name 'y_feature' is not defined
