# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;

df = pd.read_csv(r"C:\Users\pdhau\OneDrive\Desktop\Third semester\AI AND ML\placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.tail()
# Out:
#      cgpa  package
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33

# %%
x_feature = df[['cgpa']]
y_feature = df['package']

# %%
plt. xlabel('cgpa')
plt. ylabel('package')
plt. scatter(x_feature,y_feature)

# %%
from sklearn.model_selection import train_test_split

# %%
print(x_feature.shape, y_feature.shape)
# Out:
# (200, 1) (200,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_feature,y_feature,test_size=0.5,random_state=5)

# %%
from sklearn.linear_model import LinearRegression

# %%
model= LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict([[5]])
# Out:
# c:\Users\pdhau\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.83787318])

# %%
plt.scatter(x_feature,y_feature)
plt.plot(x_train,model.predict(x_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')
