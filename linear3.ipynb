# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\pdhau\OneDrive\Desktop\Third semester\AI AND ML\Salary_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.tail()
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
x_feature = df[['Salary']]
y_feature = df['YearsExperience']

# %%
plt.xlabel('Salary')
plt.ylabel('YearsExperience')
plt.scatter(x_feature,y_feature)

# %%
from sklearn.model_selection import train_test_split

# %%
print (x_feature.shape,y_feature.shape)
# Out:
# (30, 1) (30,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_feature,y_feature, test_size=0.4, random_state=4)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()
