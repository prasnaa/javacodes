# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
Data = pd.read_csv(r"C:\Users\pdhau\OneDrive\Desktop\Third semester\AI AND ML\Student_Performance.csv")

# %%
Data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
X = Data.drop(columns=['Performance Index'],axis=1)
y = Data['Performance Index']

# %%
X.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced
# 0                                 1
# 1                                 2
# 2                                 2
# 3                                 2
# 4                                 5

# %%
X = pd.get_dummies(X,drop_first=True,dtype=int)
X.head()
# Out:
#    Hours Studied  Previous Scores  Sleep Hours  \
# 0              7               99            9
# 1              4               82            4
# 2              8               51            7
# 3              5               52            5
# 4              7               75            8
#
#    Sample Question Papers Practiced  Extracurricular Activities_Yes
# 0                                 1                               1
# 1                                 2                               0
# 2                                 2                               1
# 3                                 2                               1
# 4                                 5                               0

# %%
from sklearn .model_selection import train_test_split;
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=20)

# %%
#Standarizing the dataset with standard scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train= scaler.fit_transform(X_train)
x_test= scaler.transform(X_test)

# %%
X_train
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 2018              8               76            6
# 6315              3               49            8
# 1640              8               74            5
# 5599              5               82            5
# 1278              9               78            8
# ...             ...              ...          ...
# 3915              4               67            7
# 9620              5               86            7
# 7068              6               99            4
# 7391              1               65            5
# 4367              3               77            8
#
#       Sample Question Papers Practiced  Extracurricular Activities_Yes
# 2018                                 5                               1
# 6315                                 3                               0
# 1640                                 6                               1
# 5599                                 2                               0
# ...

# %%
from sklearn.linear_model import LinearRegression
regression= LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_test)

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae = mean_absolute_error(y_test ,y_pred)
mse = mean_squared_error(y_test ,y_pred=y_pred)
score = r2_score(y_test, y_pred)
rmse = np.sqrt(mse)
print(f"Mean square error is {mse}")
print(f"Mean absolute error is {mae}")
print(f"r2 score is {score}")
print(f"root mean square error is {rmse}")
# Out:
# Mean square error is 4.066797830681561
# Mean absolute error is 1.6026639455508809
# r2 score is 0.9889888655986876
# root mean square error is 2.0166303158193277

# %%
import pickle
pickle.dump(regression,open('housing.pkl','wb'))

# %%
import pickle
pickle = pickle.load(open('housing.pkl','rb'))

# %%
X = Data.drop(columns=['Performance Index'],axis=1)
y = Data['Performance Index']

# %%
X = pd.get_dummies(X,drop_first=True,dtype=int)
X.head()
# Out:
#    Hours Studied  Previous Scores  Sleep Hours  \
# 0              7               99            9
# 1              4               82            4
# 2              8               51            7
# 3              5               52            5
# 4              7               75            8
#
#    Sample Question Papers Practiced  Extracurricular Activities_Yes
# 0                                 1                               1
# 1                                 2                               0
# 2                                 2                               1
# 3                                 2                               1
# 4                                 5                               0

# %%
residuals = y_test-y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 residuals = y_test-y_pred
#
# NameError: name 'y_test' is not defined

# %%
import seaborn as sns
sns.displot(residuals,kind='kde')
